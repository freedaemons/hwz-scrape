# %%
import requests as re
import pandas as pd
import numpy as np
import os
from bs4 import BeautifulSoup

# %% [markdown]
# Today the goal is to see how much improvement we can get by threading API calls on a single network card

# %%
pd.set_option('display.max_colwidth', -1)

# %%
allThreads_csv = os.path.join("data", "allthreads-2018-04-24T1300.csv")
allThreads_df = pd.read_csv(allThreads_csv)

# %%
site_url = 'https://forums.hardwarezone.com.sg'

# %%
parentingThreads_df = allThreads_df.loc[allThreads_df['forum_url'] == 'https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/']
print(len(parentingThreads_df))
parentingThreads_df.head()
# Out:
# 154
#                                                                    forum_url  \
# 97846  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/
# 97847  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/
# 97848  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/
# 97849  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/
# 97850  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/
#
#                                                         thread  \
# 97846  Welcome to HWZ's Parenting, Kids & Early Learning forum
# 97847  Milk powder
# 97848  I suspect my child has ADHD
# 97849  Do u lose your temper when teaching your child?
# 97850  Cry when feeding
#
#                                                                                                                                thread_url
# 97846  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/welcome-hwzs-parenting-kids-early-learning-forum-5684416.html
# 97847  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-powder-5773651.html
# 97848  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/i-suspect-my-child-has-adhd-5816748.html
# 97849  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-u-lose-your-temper-when-teaching-your-child-5785587.html
# 97850  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/cry-when-feeding-5723877.html

# %%
def getPosts(thread_url):
    print(thread_url)
    lastThreadPage = False
    thread_cols = ['thread_url', 'userid', 'timestamp', 'post_text'] #, 'post_number', 'post_order', 'first_quote_post_number', 'likes_userid'
    thread_df = pd.DataFrame(columns=thread_cols)
    thread_page_url = thread_url

    while(not lastThreadPage):
        #print(thread_page_url)
        r3 = re.get(thread_page_url)
        thread_page = r3.text
        thread_page_soup = BeautifulSoup(thread_page, 'html.parser')

        if (thread_page_soup.find('a', text='Next ›') == None):
            lastThreadPage = True
        else:
            thread_page_url = site_url + thread_page_soup.find('a', text='Next ›')['href']

        thread_page_posts = thread_page_soup.find('div', {'id': 'posts'})
        
        try: 
            for post in thread_page_posts.find_all('div', {'class': 'post-wrapper'}):
                userid_url = post.find('a', {'class': 'bigusername'})['href']
                userid = ''.join(filter(lambda x: x.isdigit(), userid_url))

                datetime_raw = post.find('a', {'name': lambda x: x and x.find('post') == 0}).nextSibling.strip()
                date_list = datetime_raw.split(',')[0].split('-')
                iso_date = '-'.join(list(reversed(date_list)))
                hour = int(datetime_raw.split(' ')[1][0:2])
                if(datetime_raw.split(' ')[2] == 'PM' and hour < 12):
                    hour += 12
                hour_str = str(hour)
                if(hour < 10):
                    hour_str = '0' + str(hour)
                minute = datetime_raw.split(':')[1][0:2]
                iso_datetime = iso_date + 'T' + hour_str + ':' + minute

                post_text = ""
                try:
                    post_text = post.find('div', {'class': 'post_message'}).get_text(' ', strip=True)
                except AttributeError as e: 
                    pass

                row = pd.DataFrame([[thread_url, userid, iso_datetime, post_text]], columns=thread_cols)
                if(len(thread_df)==0):
                    thread_df = row
                else:
                    thread_df = thread_df.append(row, ignore_index=True) #df.append doesn't work inplace
        except:
            row = pd.DataFrame([[thread_url, "", "", ""]], columns=thread_cols) #posts missing, thread may have been deleted
            if(len(thread_df)==0):
                thread_df = row
            else:
                thread_df = thread_df.append(row, ignore_index=True) #df.append doesn't work inplace
    return thread_df

# %% [markdown]
# Let's determine the baseline time for crawling an extract.

# %%
# %time parentingPosts_df = pd.concat([getPosts(threadUrl) for threadUrl in parentingThreads_df['thread_url']])
print(len(parentingPosts_df))
# Out:
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397
html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/rich-parent-acs-sec-school-boy-sued-principal-confiscating-iphone%85-5632222.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/we-have-lots-more-autistic-children-nowadays-5633506.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/%5Bglgt%5D-milk-milk-however-fancy-marketing-josephine-teo-5617616.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/father-mother-shoot-din-diao-little-girl-public-jurong-west-5621383.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/95%25-buyers-go-premium-powder-competition-commission-singapore-ccs-5616398.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/who-already-decided-next-time-wont-have-kids-5619908.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/ntuc-fairprice-charges-%246-more-than-medical-hall-baby-milk-powder-5615162.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/%5Bmilk-formula%5D-come-see-how-fkn-stupid-sg-parents-5618450.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-you-look-down-ppl-who-buy-cheap-milk-power-their-baby-5617712.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/why-sinkie-parents-want-buy-atas-milk-their-babies-5617066.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/mothers-shocked-about-formula-milk-companies-marketing-costs-5616312.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/why-has-milk-price-go-up-so-fast-5588945.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/adopt-give-birth-better-5613113.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-not-healthy-5606833.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/guys-amdk-use-cane-whack-their-chewren-only-chinese-do-5608063.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/stop-parental-alienation-5596019.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/your-children-will-go-through-same-economic-fate-you-5599564.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/guys-if-ur-son-dotter-study-primary-7-8-last-time-5599408.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-u-invest-ur-child-saving-5591563.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/need-parents-advice-mindchamps-vs-learning-lab-5595773.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/%5Bconservative-calculation%5D-joy-parenthood-worth-5586075.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/cost-raising-kids-can-dramatically-lowered-not-sending-kids-tuition-5571739.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/teacher-lost-control-scolds-chee-bye-student-5578876.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/if-your-wife-completely-hates-seeing-yr-mum-would-u-still-let-yr-mum-stay-yr-flat-5574988.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/anybody-knows-child-care-centre-5567401.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/coloring-pages-kids-5325566.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/child-swimming-classes-3932902.html
# Wall time: 9min 34s
# 9755

# %%
parentingPosts_df.head()
# Out:
#                                                                                                                            thread_url  \
# 0  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/welcome-hwzs-parenting-kids-early-learning-forum-5684416.html
# 0  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-powder-5773651.html
# 1  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-powder-5773651.html
# 2  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-powder-5773651.html
# 3  https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-powder-5773651.html
#
#    userid         timestamp  \
# 0  651883  2017-09-04T09:57
# 0  648613  2018-02-11T12:07
# 1  144455  2018-02-11T12:11
# 2  700475  2018-02-11T20:39
# 3  650196  2018-02-12T12:17
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     post_text
# 0  Hi HWZoners, We realize that many in Singapore have grown up with HardwareZone in its nearly 20-year operation and while we have forums to discuss on higher education, wedding matters, housing and furniture, based on the discussions in EDMW, we noticed there's a need for a place to discuss on the next stage - having kids and bringing them up. Hence, we've created this new section which will gather all discussions related to parenting, child upbringing and kids education! To all Beer Dads and Wine Moms out there, we hope you'll enjoy this new arrangement, so please channel all your discussions to this new forum!
# 0  where do you guys normally buy? my infant likes mamil gold, i buy from fairprice $50 for 800g tin - wondering where usually is cheaper besides JB
# 1  i usually buy from lazada. use liveup for 5% rebate, shopback and use lazada discount code.
# 2  You can try those chinese medical shops, heard if you return the tin cover will be entitled to further discount.
# 3  A lot of medical halls has it cheaper..

# %%
"""Deal with unusual unicode characters in the post text"""
parentingPosts_df['post_text'] = parentingPosts_df['post_text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))

# %%
parentingPosts_csv = os.path.join("data", "parentingposts-2018-04-24T1300.csv")
parentingPosts_df.to_csv(parentingPosts_csv, encoding='utf-8', index=False)

# %% [markdown]
# In the interim, get the threads for specific forums and write to file

# %%
#Selectively retrieving threads from forums of interest
foi = []
#foi.append("https://forums.hardwarezone.com.sg/current-affairs-lounge-17/")
#foi.append("https://forums.hardwarezone.com.sg/money-mind-210/")
foi.append("https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/")
foi.append("https://forums.hardwarezone.com.sg/stocks-shares-indices-92/")
foi.append("https://forums.hardwarezone.com.sg/eat-drink-man-woman-16/")
for forum_url in foi:
    print("Generating posts for " + str(forum_url) + " ...")
    threads_df = allThreads_df.loc[allThreads_df['forum_url'] == forum_url]
    forum_posts_df = pd.concat([getPosts(threadUrl) for threadUrl in threads_df['thread_url']])
    forum_posts_df['post_text'] = forum_posts_df['post_text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
    forum_posts_csv = os.path.join("data", ''.join(char for char in forum_url.split('/')[3] if not char.isdigit()).strip('-') + "-2018-04-24T1300.csv")
    forum_posts_df.to_csv(forum_posts_csv, encoding='utf-8', index=False)
    print('Posts for ' + str(forum_url) + " written to " + str(forum_posts_csv))
print('Done')
# Out:
# Generating posts for https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/ ...
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/report-credit-card-roadshows-3798899.html
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/credit-card-charges-fees-1932442.html
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/best-funds-transfer-rate-now-2996124.html
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/best-card-overseas-spending-3697041.html
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/2017-credit-card-charge-redeem-promotion-5571957.html
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/credit-card-wiki-5593995.html
# https://forums.hardwarezone.com.sg/credit-cards-line-credit-facilities-243/debt-consolidation-plan-5552242.html
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c0f95714b73f> in <module>()
#       9     print("Generating posts for " + str(forum_url) + " ...")
#      10     threads_df = allThreads_df.loc[allThreads_df['forum_url'] == forum_url]
# ---> 11     forum_posts_df = pd.concat([getPosts(threadUrl) for threadUrl in threads_df['thread_url']])
#      12     forum_posts_df['post_text'] = forum_posts_df['post_text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
#      13     forum_posts_csv = os.path.join("data", ''.join(char for char in forum_url.split('/')[3] if not char.isdigit()).strip('-') + "-2018-04-24T1300.csv")
#
# <ipython-input-11-c0f95714b73f> in <listcomp>(.0)
#       9     print("Generating posts for " + str(forum_url) + " ...")
#      10     threads_df = allThreads_df.loc[allThreads_df['forum_url'] == forum_url]
# ---> 11     forum_posts_df = pd.concat([getPosts(threadUrl) for threadUrl in threads_df['thread_url']])
#      12     forum_posts_df['post_text'] = forum_posts_df['post_text'].map(lambda x: x.encode('unicode-escape').decode('utf-8'))
#      13     forum_posts_csv = os.path.join("data", ''.join(char for char in forum_url.split('/')[3] if not char.isdigit()).strip('-') + "-2018-04-24T1300.csv")
#
# <ipython-input-6-d3310175ae24> in getPosts(thread_url)
#       8     while(not lastThreadPage):
#       9         #print(thread_page_url)
# ---> 10         r3 = re.get(thread_page_url)
#      11         thread_page = r3.text
#      12         thread_page_soup = BeautifulSoup(thread_page, 'html.parser')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %%
def processQueryList(query_list, store=None):
    """Process a subset of the list of queries that needs to be made, storing posts in a dataframe"""
    if store is None:
        store = {}
    for url in query_list:
        #Store list of dataframes of posts from each thread into the dictionary
        store[str(url)] = getPosts(url)
    return store

# %% [markdown]
# Since getPosts handles requests threadwise already, we'll just try to parallelize thread retrieval.

# %%
from threading import Thread

def threadedApiCall(nthreads, master_query_list):
    store = {}
    threads = []
    sublistLength = len(master_query_list)//nthreads
    #split the master query list
    sublists = [master_query_list[x:x+sublistLength] for x in range(0,len(master_query_list), sublistLength)]
    for sublist in sublists:
        t = Thread(target=processQueryList, args=(sublist, store))
        threads.append(t)

    #start the threads
    [t.start() for t in threads]
    #wait for the threads to finish
    [t.join() for t in threads]
    
    return pd.concat(thread_posts for thread_posts in list(store.values()))

# %%
# %%time
parentingPosts_pdf = threadedApiCall(10, parentingThreads_df['thread_url'])
print(len(parentingPosts_pdf))
# Out:
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/welcome-hwzs-parenting-kids-early-learning-forum-5684416.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/joie-car-seat-5805701.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/marriage-life-kids-5762340.htmlhttps://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/gynae-recommend-5725994.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/discriminatory-treatment-antenatal-care-costs-local-men-foreign-wives-5746744.html
#
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/last-times-now-having-kid-s-what-purpose-s-5701084.htmlhttps://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/primary-school-transfer-5721788.html
#
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/seller-scammed-jjb-bag-buyer-forum-members-continues-harass-5699771.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/child-custody-how-many-parents-here-managed-get-shared-care-control-5630917.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-you-look-down-ppl-who-buy-cheap-milk-power-their-baby-5617712.htmlhttps://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/if-your-wife-completely-hates-seeing-yr-mum-would-u-still-let-yr-mum-stay-yr-flat-5574988.html
#
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/milk-powder-5773651.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/noise-sensitive-baby-5786142.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/endowment-5698264.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/mischief-during-k1-2-a-5693251.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/what-do-when-wife-suddenly-go-into-labour-5739305.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/country-maid-better-newborn-baby-care-5809204.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/pregnancy-insurance-5705328.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/infant-care-advice-needed-5688994.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/why-sinkie-parents-want-buy-atas-milk-their-babies-5617066.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/singapore-has-more-fun-than-you-think-family-day-trip-5782141.htmlhttps://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/need-help-getting-swimming-lesson-discounts-my-boy-5784437.htmlhttps://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/questions-regarding-children-autism-5763114.html
#
#
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/i-think-too-early-my-3-yr-old-start-nursery-5751518.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-u-feel-pri-1-kids-need-tuition-5559444.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/i-suspect-my-child-has-adhd-5816748.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-you-cane-your-kids-5752742.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/toys-r-us-bankrupt-latest-news-5693248.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/resigning-after-maternity-leave-must-pay-back-benefits-5754678.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/kinderland-sengkang-5677032.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/do-u-lose-your-temper-when-teaching-your-child-5785587.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/little-footprints-hfmd-5712629.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/can-zeh-zeh-please-stop-pm-me-im-not-interested-u-5762766.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/challenges-young-parents-5712911.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/party-banner-will-spark-your-creativity-bring-you-joy-satisfaction-5693109.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397/anybody-still-call-their-parents-5643047.html
# https://forums.hardwarezone.com.sg/parenting-kids-early-learning-397